# %%
from pandas import read_csv

df = read_csv('Time_Series_For_Clustering_El_Paso_Final.csv', index_col=False)

# %%
import re
import pandas as pd

non_decimal = re.compile(r'[^\d.]+')

list_of_training_df = []

for i in range(1, 524):
    
    list_of_row_components = []
    
    current_row = df.iloc[i]
    current_row = current_row.iloc[1:]
    
    for j, row in current_row.iteritems():
        
        current_row_components = row.split(', ')
        current_row_components_replaced = []

        for idx, component in enumerate(current_row_components):

            result = non_decimal.sub('', current_row_components[idx])
            current_row_components_replaced.append(float(result))

        list_of_row_components.append(current_row_components_replaced)

    var1 = []
    var2 = []
    var3 = []
    var4 = []
    var5 = []
    var6 = []
    varout = []

    for element in list_of_row_components:

        var1.append(element[0])
        var2.append(element[2])
        var3.append(element[3])
        var4.append(element[4])
        var5.append(element[5])
        var6.append(element[6])
        varout.append(element[1])

    dict_temp = {'var1': var1, 'var2': var2, 'var3': var3, 'var4': var4, 'var5': var5, 'var6': var6, 'varout': varout}

    df_temp = pd.DataFrame(dict_temp)

    list_of_training_df.append(df_temp)

# %%
list_of_training_df
# Out:
# [    var1   var2    var3  var4  var5  var6  varout
#  0   36.0  428.0  1949.0   2.0  10.9   7.3    97.0
#  1   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
#  2   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
#  3   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
#  4   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
#  5   36.3  955.0  1949.0   2.0  11.0   7.0    97.0
#  6   36.3  955.0  1949.0   2.0  11.0   7.3    96.9
#  7   36.3  983.0  1949.0   2.0  11.0   7.3    96.9
#  8   36.3  983.0  1949.0   2.0  11.0   7.3    96.9
#  9   36.3  983.0  1949.0   2.0  11.0   7.3    96.9
#  10  36.3  983.0  1949.0   2.0  11.0   7.3    96.9
#  11  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
#  12  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
#  13  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
#  14  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
#  15  36.3  422.0  1949.0   2.0   9.7   7.3    97.0
#  16  36.3  369.0  1949.0   2.0   9.7   7.3    97.0
# ...

# %%
list_of_training_df[3]
# Out:
#     var1   var2    var3  var4  var5  var6  varout
# 0   36.0   87.0  1984.0   2.0  12.8   3.0    97.0
# 1   36.0  305.0  1984.0   2.0  12.8   3.0    97.0
# 2   36.0  305.0  1984.0   2.0  12.8   3.0    97.0
# 3   36.0  305.0  1984.0   2.0  12.8   3.0    97.0
# 4   36.0  305.0  1984.0   2.0  12.8   3.0    97.0
# 5   36.3  305.0  1984.0   2.0  12.8   3.0    97.0
# 6   36.3  305.0  1984.0   2.0  12.8   3.0    97.0
# 7   36.3  397.0  1984.0   2.0  12.8   3.0    97.0
# 8   36.3  397.0  1984.0   2.0  12.8   3.0    97.0
# 9   36.3  397.0  1984.0   2.0  12.8   3.0    97.0
# 10  36.3  397.0  1984.0   2.0  12.8   3.0    97.0
# 11  36.3  397.0  1984.0   2.0  13.3   3.0    98.0
# 12  36.3  397.0  1984.0   2.0  13.3   3.0    98.0
# 13  36.3  287.0  1984.0   2.0  13.3   3.0    98.0
# 14  36.3  287.0  1984.0   2.0  13.3   3.0    98.0
# 15  36.3  287.0  1984.0   2.0  12.8   3.0    99.0
# 16  36.3  302.0  1984.0   2.0  12.8   3.0    99.0
# 17  36.3  302.0  1984.0   2.0  12.8   3.0   100.0
# ...

# %%
training_examples = []

for training_df in list_of_training_df:
#     print(training_df['var1'])
    training_examples.append(training_df)

# %%
training_examples[0]
# Out:
#     var1   var2    var3  var4  var5  var6  varout
# 0   36.0  428.0  1949.0   2.0  10.9   7.3    97.0
# 1   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
# 2   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
# 3   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
# 4   36.0  955.0  1949.0   2.0  10.9   7.3    96.9
# 5   36.3  955.0  1949.0   2.0  11.0   7.0    97.0
# 6   36.3  955.0  1949.0   2.0  11.0   7.3    96.9
# 7   36.3  983.0  1949.0   2.0  11.0   7.3    96.9
# 8   36.3  983.0  1949.0   2.0  11.0   7.3    96.9
# 9   36.3  983.0  1949.0   2.0  11.0   7.3    96.9
# 10  36.3  983.0  1949.0   2.0  11.0   7.3    96.9
# 11  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
# 12  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
# 13  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
# 14  36.3  422.0  1949.0   2.0  11.0   7.3    97.0
# 15  36.3  422.0  1949.0   2.0   9.7   7.3    97.0
# 16  36.3  369.0  1949.0   2.0   9.7   7.3    97.0
# 17  36.3  369.0  1949.0   2.0   9.7   7.3    86.0
# ...

# %% [markdown]
# # The cell below utilizes VAR on each individual time series for each separate bridge and appends their rmse results into individual lists

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
train[:2]
# Out:
# [[87.3, 28.0, 1900.0, 0.0, 4.7, 4.9, 82.0],
#  [87.3, 28.0, 1900.0, 0.0, 4.7, 4.9, 82.0]]

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tsa.statespace.varmax import VARMAX
from math import sqrt
from sklearn.metrics import mean_squared_error

rmse_VAR_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'varout'])

for item, idx in rmse_VAR_dict.items():

        rmse_VAR_dict[item] = []

for training_example in training_examples:
    
    train = training_example.iloc[0:18].values.tolist()
    valid = training_example.iloc[18:]
    
    # Get data separated from data_exog in dataset
    
    # link to help with varmax and double exponential smoothing
    # https://towardsdatascience.com/lets-forecast-your-time-series-using-classical-approaches-f84eb982212c
    
    model_VAR = VAR(endog=train)
    model_VAR_fit = model_VAR.fit(trend='nc')

    prediction_VAR = model_VAR_fit.forecast(model_VAR_fit.y, steps=len(valid))

    prediction_VAR
    prediction_VAR_list = []
    for p in prediction_VAR:
        prediction_VAR_list.append(p.tolist())

    prediction_VAR_list

    pred_VAR_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'varout'])

    for item, idx in pred_VAR_dict.items():

        pred_VAR_dict[item] = []

    for pred in prediction_VAR_list:
        
        pred_VAR_dict['var1'].append(pred[0])
        pred_VAR_dict['var2'].append(pred[1])
        pred_VAR_dict['var3'].append(pred[2])
        pred_VAR_dict['var4'].append(pred[3])
        pred_VAR_dict['var5'].append(pred[4])
        pred_VAR_dict['var6'].append(pred[5])
        pred_VAR_dict['varout'].append(pred[6])

    cols = training_examples[8].columns

    #check rmse
    for i in cols:
        rmse_VAR_dict[i].append(sqrt(mean_squared_error(pred_VAR_dict[i], valid[i])))
#         print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred_dict[i], valid[i])))
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# ...

# %% [markdown]
# # An average rmse is calculated across all of the individual bridge rmse scores for each variable

# %%
print('rmse scores for VAR model results \n')

print('var1 rmse: ' + str(Average(rmse_VAR_dict['var1'])))
print('var2 rmse: ' + str(Average(rmse_VAR_dict['var2'])))
print('var3 rmse: ' + str(Average(rmse_VAR_dict['var3'])))
print('var4 rmse: ' + str(Average(rmse_VAR_dict['var4'])))
print('var5 rmse: ' + str(Average(rmse_VAR_dict['var5'])))
print('var6 rmse: ' + str(Average(rmse_VAR_dict['var6'])))
print('varout rmse: ' + str(Average(rmse_VAR_dict['varout'])))
# Out:
# rmse scores for VAR model results
#
# var1 rmse: 8019638.850354504
# var2 rmse: 16981077600.45424
# var3 rmse: 0.06108288210195237
# var4 rmse: 30.07270086384217
# var5 rmse: 23207569.29969302
# var6 rmse: 8002357.233123328
# varout rmse: 1731132370.2495914

# %% [markdown]
# # Now we try applying some MinMaxScaling to the original dataset and test VAR again

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
from math import sqrt
from sklearn.metrics import mean_squared_error

rmse_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'varout'])

for item, idx in rmse_dict.items():

        rmse_dict[item] = []

for training_example in training_examples:
    
    train = training_example.iloc[0:18].values.tolist()
    valid = training_example.iloc[18:]
    
    train = scaler.fit_transform(train)
    
    valid = scaler.fit_transform(valid)
    
    model = VAR(endog=train)
    model_fit = model.fit(trend='nc')

    prediction = model_fit.forecast(model_fit.y, steps=len(valid))

    prediction
    prediction_list = []
    for p in prediction:
        prediction_list.append(p.tolist())

    pred_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'varout'])

    for item, idx in pred_dict.items():

        pred_dict[item] = []

    for pred in prediction_list:
        
        pred_dict['var1'].append(pred[0])
        pred_dict['var2'].append(pred[1])
        pred_dict['var3'].append(pred[2])
        pred_dict['var4'].append(pred[3])
        pred_dict['var5'].append(pred[4])
        pred_dict['var6'].append(pred[5])
        pred_dict['varout'].append(pred[6])
        
    val_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'varout'])

    for item, idx in val_dict.items():

        val_dict[item] = []

    for val in valid:
        
        val_dict['var1'].append(val[0])
        val_dict['var2'].append(val[1])
        val_dict['var3'].append(val[2])
        val_dict['var4'].append(val[3])
        val_dict['var5'].append(val[4])
        val_dict['var6'].append(val[5])
        val_dict['varout'].append(val[6])

    cols = training_examples[8].columns

    #check rmse
    for i in cols:
        rmse_dict[i].append(sqrt(mean_squared_error(pred_dict[i], val_dict[i])))
#         print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred_dict[i], valid[i])))
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# ...

# %% [markdown]
# # An average rmse is calculated across all of the individual bridge rmse scores for each variable

# %%
print('var1 rmse: ' + str(Average(rmse_dict['var1'])))
print('var2 rmse: ' + str(Average(rmse_dict['var2'])))
print('var3 rmse: ' + str(Average(rmse_dict['var3'])))
print('var4 rmse: ' + str(Average(rmse_dict['var4'])))
print('var5 rmse: ' + str(Average(rmse_dict['var5'])))
print('var6 rmse: ' + str(Average(rmse_dict['var6'])))
print('varout rmse: ' + str(Average(rmse_dict['varout'])))
# Out:
# var1 rmse: 6.590626757322692
# var2 rmse: 28.708599909917098
# var3 rmse: 0.021819818499934935
# var4 rmse: 0.5520603757405618
# var5 rmse: 36.46382221712161
# var6 rmse: 29.21968684495763
# varout rmse: 95.53317934909036

# %% [markdown]
# # Now add weather data to original data and test VAR again

# %%
from pandas import read_csv

df = read_csv('Time_Series_For_Clustering_El_Paso_Final.csv')

# %%
import re
import pandas as pd

non_decimal = re.compile(r'[^\d.]+')

list_of_training_df = []
list_of_row_components = []

for i in range(1, 524):
    
    current_row = df.iloc[i]
    
    bridge_id = current_row.iloc[0]
    
    current_row = current_row.iloc[1:]
    
    for j, row in current_row.iteritems():
        
        current_row_components = row.split(', ')
        current_row_components_replaced = []
        
        current_row_components_replaced.append(bridge_id)

        for idx, component in enumerate(current_row_components):

            result = non_decimal.sub('', current_row_components[idx])
            current_row_components_replaced.append(float(result))

        list_of_row_components.append(current_row_components_replaced)

# %% [markdown]
# # Append the weather data to the end of each time step

# %%
start_year = 1998
last_year = 2019

rows = []

df_NOAA = read_csv('NBI_NOAA_Integrated.csv')

for i, example in enumerate(list_of_row_components):
        
        row = df_NOAA.loc[(df_NOAA['STRUCTURE_NUMBER_008'] == list_of_row_components[i][0]) & (df_NOAA['EVALUATION_YEAR'] == start_year)]
        
        if len(row) == 0:
            row = prev_row
        
        for idx, r in row.iterrows():  
            list_of_row_components[i].append(r['prcp_avg'])
            list_of_row_components[i].append(r['snow_avg'])
            list_of_row_components[i].append(r['snwd_avg'])
        
        start_year += 1
        
        if start_year > last_year:
            start_year = 1998
            
        prev_row = row
        prev_row['EVALUATION_YEAR'] = start_year
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,33,38,39,40,41,43,71,78,81,104,108,109,110,111,116,132,135) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\tobby\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Ensure each element in the list of lists is a float

# %%
for idx, element in enumerate(list_of_row_components):
    for i in range(1, len(element)):
        list_of_row_components[idx][i] = float(list_of_row_components[idx][i])

# %% [markdown]
# # Remove the structure number from each row and add to new training_examples list

# %%
training_examples_no_struct_num = []

for component in list_of_row_components:
#     print(example[1:])
    training_examples_no_struct_num.append(component[1:])

# %%
len(training_examples_no_struct_num)
# Out:
# 11506

# %%
counter = 0
training_examples = []

for i in range(523):
    
    temp_list = []
    
    for i in range(22):
        
        temp_list.append(training_examples_no_struct_num[counter])
        
        counter += 1
        
    training_examples.append(pd.DataFrame(temp_list, columns=['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10']))

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
from math import sqrt
from sklearn.metrics import mean_squared_error

df_NOAA = read_csv('NBI_NOAA_Integrated.csv')

rmse_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10'])

for item, idx in rmse_dict.items():

        rmse_dict[item] = []

for training_example in training_examples:
    
    train = training_example.iloc[0:18].values.tolist()
    valid = training_example.iloc[18:]
    
    model = VAR(endog=train)
    model_fit = model.fit(trend='nc')

    prediction = model_fit.forecast(model_fit.y, steps=len(valid))

    prediction
    prediction_list = []
    for p in prediction:
        prediction_list.append(p.tolist())

    prediction_list

    pred_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10'])

    for item, idx in pred_dict.items():

        pred_dict[item] = []

    for pred in prediction_list:
        
        pred_dict['var1'].append(pred[0])
        pred_dict['var2'].append(pred[1])
        pred_dict['var3'].append(pred[2])
        pred_dict['var4'].append(pred[3])
        pred_dict['var5'].append(pred[4])
        pred_dict['var6'].append(pred[5])
        pred_dict['var7'].append(pred[6])
        pred_dict['var8'].append(pred[7])
        pred_dict['var9'].append(pred[8])
        pred_dict['var10'].append(pred[9])

    cols = training_examples[8].columns

    #check rmse
    for i in cols:
        rmse_dict[i].append(sqrt(mean_squared_error(pred_dict[i], valid[i])))
#         print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred_dict[i], valid[i])))
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# ...

# %% [markdown]
# # An average rmse is calculated across all of the individual bridge rmse scores for each variable

# %%
print('var1 rmse: ' + str(Average(rmse_dict['var1'])))
print('var2 rmse: ' + str(Average(rmse_dict['var2'])))
print('var3 rmse: ' + str(Average(rmse_dict['var3'])))
print('var4 rmse: ' + str(Average(rmse_dict['var4'])))
print('var5 rmse: ' + str(Average(rmse_dict['var5'])))
print('var6 rmse: ' + str(Average(rmse_dict['var6'])))
print('var7 rmse: ' + str(Average(rmse_dict['var7'])))
print('var8 rmse: ' + str(Average(rmse_dict['var8'])))
print('var9 rmse: ' + str(Average(rmse_dict['var9'])))
print('var10 rmse: ' + str(Average(rmse_dict['var10'])))
# Out:
# var1 rmse: 9426786.026275158
# var2 rmse: 2989381478.1925464
# var3 rmse: 5162738897.77058
# var4 rmse: 5.118527320495392
# var5 rmse: 265035.394192043
# var6 rmse: 5481037.550954997
# var7 rmse: 8886596.383648993
# var8 rmse: 33227085.40751316
# var9 rmse: 461796131.76621425
# var10 rmse: 356946430.47804314

# %% [markdown]
# # Now we test VAR with normalized + weather data

# %%
from pandas import read_csv

df = read_csv('Time_Series_For_Clustering_El_Paso_Final.csv')

# %%
import re
import pandas as pd

non_decimal = re.compile(r'[^\d.]+')

list_of_training_df = []
list_of_row_components = []

for i in range(1, 524):
    
    current_row = df.iloc[i]
    
    bridge_id = current_row.iloc[0]
    
    current_row = current_row.iloc[1:]
    
    for j, row in current_row.iteritems():
        
        current_row_components = row.split(', ')
        current_row_components_replaced = []
        
        current_row_components_replaced.append(bridge_id)

        for idx, component in enumerate(current_row_components):

            result = non_decimal.sub('', current_row_components[idx])
            current_row_components_replaced.append(float(result))

        list_of_row_components.append(current_row_components_replaced)

# %% [markdown]
# # Append the weather data to the end of each time step

# %%
start_year = 1998
last_year = 2019

rows = []

df_NOAA = read_csv('NBI_NOAA_Integrated.csv')

for i, example in enumerate(list_of_row_components):
        
        row = df_NOAA.loc[(df_NOAA['STRUCTURE_NUMBER_008'] == list_of_row_components[i][0]) & (df_NOAA['EVALUATION_YEAR'] == start_year)]
        
        if len(row) == 0:
            row = prev_row
        
        for idx, r in row.iterrows():  
            list_of_row_components[i].append(r['prcp_avg'])
            list_of_row_components[i].append(r['snow_avg'])
            list_of_row_components[i].append(r['snwd_avg'])
        
        start_year += 1
        
        if start_year > last_year:
            start_year = 1998
            
        prev_row = row
        prev_row['EVALUATION_YEAR'] = start_year
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,33,38,39,40,41,43,71,78,81,104,108,109,110,111,116,132,135) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\tobby\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Ensure each element in the list of lists is a float

# %%
for idx, element in enumerate(list_of_row_components):
    for i in range(1, len(element)):
        list_of_row_components[idx][i] = float(list_of_row_components[idx][i])

# %% [markdown]
# # Remove the structure number from each row and add to new training_examples list

# %%
training_examples_no_struct_num = []

for component in list_of_row_components:
#     print(example[1:])
    training_examples_no_struct_num.append(component[1:])

# %%
len(training_examples_no_struct_num)
# Out:
# 11506

# %%
counter = 0
training_examples = []

for i in range(523):
    
    temp_list = []
    
    for i in range(22):
        
        temp_list.append(training_examples_no_struct_num[counter])
        
        counter += 1
        
    training_examples.append(pd.DataFrame(temp_list, columns=['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10']))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
from statsmodels.tsa.vector_ar.var_model import VAR
from math import sqrt
from sklearn.metrics import mean_squared_error

df_NOAA = read_csv('NBI_NOAA_Integrated.csv')

rmse_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10'])

for item, idx in rmse_dict.items():

        rmse_dict[item] = []

for training_example in training_examples:
    
    train = training_example.iloc[0:18].values.tolist()
    valid = training_example.iloc[18:]
    
    train = scaler.fit_transform(train)
    
    valid = scaler.fit_transform(valid)
    
    model = VAR(endog=train)
    model_fit = model.fit(trend='nc')

    prediction = model_fit.forecast(model_fit.y, steps=len(valid))

    prediction
    prediction_list = []
    for p in prediction:
        prediction_list.append(p.tolist())

    prediction_list

    pred_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10'])

    for item, idx in pred_dict.items():

        pred_dict[item] = []

    for pred in prediction_list:
        
        pred_dict['var1'].append(pred[0])
        pred_dict['var2'].append(pred[1])
        pred_dict['var3'].append(pred[2])
        pred_dict['var4'].append(pred[3])
        pred_dict['var5'].append(pred[4])
        pred_dict['var6'].append(pred[5])
        pred_dict['var7'].append(pred[6])
        pred_dict['var8'].append(pred[7])
        pred_dict['var9'].append(pred[8])
        pred_dict['var10'].append(pred[9])
        
    val_dict = dict.fromkeys(['var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8', 'var9', 'var10'])

    for item, idx in val_dict.items():

        val_dict[item] = []

    for val in valid:
        
        val_dict['var1'].append(val[0])
        val_dict['var2'].append(val[1])
        val_dict['var3'].append(val[2])
        val_dict['var4'].append(val[3])
        val_dict['var5'].append(val[4])
        val_dict['var6'].append(val[5])
        val_dict['var7'].append(val[6])
        val_dict['var8'].append(val[7])
        val_dict['var9'].append(val[8])
        val_dict['var10'].append(val[9])

    cols = training_examples[8].columns

    #check rmse
    for i in cols:
        rmse_dict[i].append(sqrt(mean_squared_error(pred_dict[i], val_dict[i])))
#         print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred_dict[i], valid[i])))
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,33,38,39,40,41,43,71,78,81,104,108,109,110,111,116,132,135) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:36: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# ...

# %% [markdown]
# # An average rmse is calculated across all of the individual bridge rmse scores for each variable

# %%
print('var1 rmse: ' + str(Average(rmse_dict['var1'])))
print('var2 rmse: ' + str(Average(rmse_dict['var2'])))
print('var3 rmse: ' + str(Average(rmse_dict['var3'])))
print('var4 rmse: ' + str(Average(rmse_dict['var4'])))
print('var5 rmse: ' + str(Average(rmse_dict['var5'])))
print('var6 rmse: ' + str(Average(rmse_dict['var6'])))
print('var7 rmse: ' + str(Average(rmse_dict['var7'])))
print('var8 rmse: ' + str(Average(rmse_dict['var8'])))
print('var9 rmse: ' + str(Average(rmse_dict['var9'])))
print('var10 rmse: ' + str(Average(rmse_dict['var10'])))
# Out:
# var1 rmse: 42.37135789810237
# var2 rmse: 127.861938047599
# var3 rmse: 21.587070947528716
# var4 rmse: 0.022617104151242358
# var5 rmse: 8.854454670614096
# var6 rmse: 38.48642755136818
# var7 rmse: 31.660658170599802
# var8 rmse: 92.49507902869846
# var9 rmse: 162.13139067218472
# var10 rmse: 103.5211278081795

# %%
data = []
data_exog = []

for training_df in list_of_training_df:
#     print(training_df['var1'][1])
    data.append([training_df['var1'][1], training_df['varout'][1]])
    data_exog.append([training_df['var2'][1], training_df['var3'][1], training_df['var4'][1],
                      training_df['var5'][1], training_df['var6'][1]])

# %%
data
# Out:
# [[36.0, 96.9],
#  [36.0, 70.9],
#  [36.0, 84.3],
#  [36.0, 97.0],
#  [36.0, 80.5],
#  [36.0, 85.7],
#  [36.0, 96.3],
#  [36.0, 96.9],
#  [36.0, 79.4],
#  [36.0, 98.5],
#  [31.5, 48.8],
#  [46.8, 77.0],
#  [36.0, 65.5],
#  [36.0, 97.6],
#  [31.5, 79.8],
#  [37.8, 86.8],
#  [36.0, 77.0],
#  [36.0, 96.9],
#  [29.7, 87.5],
#  [36.0, 91.0],
#  [36.0, 97.0],
#  [81.9, 99.9],
#  [36.0, 95.1],
#  [36.0, 82.4],
#  [36.0, 96.7],
#  [99.9, 97.2],
#  [79.2, 99.8],
#  [32.4, 75.0],
#  [36.0, 81.8],
#  [53.1, 72.7],
#  [60.3, 86.0],
#  [48.6, 90.4],
#  [55.8, 78.6],
#  [53.1, 98.9],
#  [30.6, 40.6],
#  [76.5, 81.9],
#  [36.0, 96.6],
#  [36.0, 74.0],
#  [36.0, 69.4],
#  [36.0, 61.8],
#  [36.0, 74.5],
#  [36.0, 74.3],
#  [54.0, 96.6],
#  [36.0, 94.3],
#  [47.7, 96.2],
#  [36.0, 92.1],
#  [36.0, 91.9],
#  [36.0, 82.4],
#  [36.0, 95.1],
#  [36.0, 97.7],
#  [84.6, 96.5],
#  [67.5, 99.2],
#  [36.0, 47.9],
#  [47.7, 92.5],
#  [36.0, 95.7],
#  [36.0, 96.6],
#  [36.0, 94.4],
#  [58.5, 95.6],
# ...

# %%
import time
from statsmodels.tsa.statespace.varmax import VARMAX

start = time.time()

model = VARMAX(data, exog=data_exog, order=(5,1))
model_fit = model.fit(disp=False, maxiter=1000)

data_exog2=data_exog[-1]

# make prediction
yhat = model_fit.forecast(exog=data_exog2)
print(yhat)

model_fit.summary()

end = time.time()

print(end - start)
# Out:
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# [[62.29156798 66.82180654]]
# 8.792066812515259
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\tobby\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)

# %%
yhat
# Out:
# array([[62.28996215, 66.8179572 ]])
